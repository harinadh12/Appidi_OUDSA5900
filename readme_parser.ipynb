# %%
import os
import pandas as pd
import re
import matplotlib.pyplot as plt

# %%
class ReadMeParser:
    DATA_PATH = 'WESAD/'
    file_suffix = '_readme.txt'
    
    def read_me_parser(self):

# %%
import os
import re
import pandas as pd


PARSE_KEYS = {
    "age": {
        'Key': 'Age',
        'delimiter': ':'
    },
    "height": {
        'Key': 'Height',
        'delimiter': ':'
    },
    "weight": {
        'Key': 'Weight',
        'delimiter': ':'
    },
    "gender": {
        'Key': 'Gender',
        'delimiter': ':'
    },
    "dominant_hand": {
        'Key': 'Dominant',
        'delimiter': ':'
    },
    "coffee_today": {
        'Key': 'Did you drink coffee today',
        'delimiter': '? '
    },
    "coffee_last_hour": {
        'Key': 'Did you drink coffee within the last hour',
        'delimiter': '? '
    },
    "sports_today": {
        'Key': 'Did you do any sports today',
        'delimiter': '? '
    },
    "smoker": {
        'Key': 'Are you a smoker',
        'delimiter': '? '
    },
    "smoke_last_hour": {
        'Key': 'Did you smoke within the last hour',
        'delimiter': '? '
    },
    "feel_ill_today": {
        'Key': 'Do you feel ill today',
        'delimiter': '? '
    }
}
    
DATA_PATH = 'WESAD/'
file_suffix = '_readme.txt'



readme_paths = {sub_dir: DATA_PATH + sub_dir + '/' 
                        for sub_dir in os.listdir(DATA_PATH)
                            if re.match('^S[0-9]{1,2}$', sub_dir)}

    
def parse_readme(subject_id):
    with open(readme_paths[subject_id] + subject_id + file_suffix, 'r') as f:
        x = f.read().split('\n')

    readme_dict = {}

    for item in x:
        for key in PARSE_KEYS.keys():
            if item.startswith(PARSE_KEYS[key]['Key']):
                k,v = item.split(PARSE_KEYS[key]['delimiter'])
                readme_dict[key] = v
    return readme_dict


def parse_all_readmes():
    
    dframes = []

    for subject_id, path in readme_paths.items():
        readme_dict = parse_readme(subject_id)
        df = pd.DataFrame(readme_dict, index=[subject_id])
        dframes.append(df)

    df = pd.concat(dframes)
    df.to_csv(DATA_PATH + 'readmes.csv')

# %%
# rp.parse_all_readmes()
parse_all_readmes()
df = pd.read_csv('./WESAD/readmes.csv')
df.head()
# Out:
#   Unnamed: 0  age  height  weight   gender dominant_hand coffee_today  \
# 0         S3   27     173      69     male         right           NO
# 1        S15   28     186      83     male         right           NO
# 2         S7   28     184      74     male         right           NO
# 3        S17   29     165      55   female         right           NO
# 4        S16   24     184      69     male         right           NO
#
#   coffee_last_hour sports_today smoker smoke_last_hour feel_ill_today
# 0               NO           NO     NO              NO             NO
# 1               NO           NO     NO              NO             NO
# 2               NO          YES     NO              NO             NO
# 3               NO           NO     NO              NO             NO
# 4               NO           NO     NO              NO             NO

# %%
df.astype('object').describe()
# Out:
#        Unnamed: 0  age  height  weight gender dominant_hand coffee_today  \
# count          15   15      15      15     15            15           15
# unique         15    7      12      12      2             2            2
# top           S13   27     175      80   male         right           NO
# freq            1    5       2       3     12            14           11
#
#        coffee_last_hour sports_today smoker smoke_last_hour feel_ill_today
# count                15           15     15              15             15
# unique                1            2      2               1              2
# top                  NO           NO     NO              NO             NO
# freq                 15           13     14              15             14

# %%
df.set_index('Unnamed: 0')
df = pd.get_dummies(df,columns= [col for col in df.columns if col not in ['Unnamed: 0', 'age','height','weight']],drop_first=True)
df

# %%
# df.groupby('coffee_today').size().plot(kind='pie', autopct='%.2f')
# df.groupby('dominant_hand').size().plot(kind='pie', autopct='%.2f')
# df.groupby('gender').size().plot(kind='pie', autopct='%.2f')
df.groupby('coffee_last_hour').size().plot(kind='pie', autopct='%.2f')
# df.groupby('sports_today').size().plot(kind='pie', autopct='%.2f')
# df.smoker.value_counts().plot(kind='pie')
df.drop(['smoke_last_hour','coffee_last_hour'], axis=1, inplace=True)

# %%
df.describe()
# Out:
#              age      height     weight
# count  15.000000   15.000000  15.000000
# mean   27.466667  177.600000  73.133333
# std     2.445599    6.748545  10.273869
# min    24.000000  165.000000  54.000000
# 25%    26.500000  172.500000  67.500000
# 50%    27.000000  178.000000  75.000000
# 75%    28.000000  182.500000  80.000000
# max    35.000000  189.000000  90.000000

# %%
# with open(readme_locations['S2'] + 'S2_readme.txt' , 'r') as f:
#             x = f.read().split('\n')
# Out:
# 4

# %%
x
# Out:
# ['### Personal information ###',
#  'Age: 27',
#  'Height (cm): 175',
#  'Weight (kg): 80',
#  'Gender: male',
#  'Dominant hand: right',
#  '',
#  '### Study pre-requisites ###',
#  'Did you drink coffee today? NO',
#  'Did you drink coffee within the last hour? NO',
#  'Did you do any sports today? NO',
#  'Are you a smoker? NO',
#  'Did you smoke within the last hour? NO',
#  'Do you feel ill today? NO',
#  '',
#  '### Additional notes ###',
#  'The RespiBAN temperature sensor was not fully attached throughout the entire duration of the study protocol.',
#  '']
